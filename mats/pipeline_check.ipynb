# %%
# %load_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %autoreload
from pipeline import DataPipeline, BuilingIdsEnum
pipe = DataPipeline()

from ipywidgets import interact, IntSlider
from matplotlib.widgets import RangeSlider
from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt

pd.set_option('display.max_rows', 200)
pd.set_option('display.max_columns', None)

# %%
# main_building = pipe.get_import_data_for_building(BuilingIdsEnum.MAIN.value)
energy_df = pipe.get_main_building_consumption_data()
main_building = pipe.get_main_building_all_data()
main_building
# Out:
#                 timestamp  import_value  solar_consumption  export_value  \
# 0     2023-07-01 00:00:00          27.5           0.002687           0.0
# 1     2023-07-01 01:00:00          27.1           0.002750           0.0
# 2     2023-07-01 02:00:00          26.8           0.002937           0.0
# 3     2023-07-01 03:00:00          25.9           0.003062           0.0
# 4     2023-07-01 04:00:00          26.4           0.000035           0.0
# ...                   ...           ...                ...           ...
# 10343 2024-09-04 19:00:00          50.8           0.148164           0.0
# 10344 2024-09-04 20:00:00          52.3           0.058932           0.0
# 10345 2024-09-04 21:00:00          49.8           0.017900           0.0
# 10346 2024-09-04 22:00:00          50.4           0.017438           0.0
# 10347 2024-09-04 23:00:00          38.6           0.017267           0.0
#
#        brutto_consumption  net_consumption       building            meter_id  \
# ...

# %%
# get the data for the main building without weather data
data = pipe.merged_df
data
# find nan values
data.isna().sum()

# filer out and show nan values
nan_data = data[data.isna().any(axis=1)]
nan_data

# find the set of "timestamps" in the nan_data
# set index to timestamp
nan_data = nan_data.set_index('timestamp')
nan_data

set_timestamps = set(nan_data.index)
set_timestamps

# kanskje fjerner data hvis det mangler mer enn 12 verdier etter hverandre, ellers interpolerer vi
# Out:
# {Timestamp('2024-02-06 06:00:00'),
#  Timestamp('2024-02-06 07:00:00'),
#  Timestamp('2024-02-06 08:00:00'),
#  Timestamp('2024-02-06 09:00:00'),
#  Timestamp('2024-02-06 10:00:00'),
#  Timestamp('2024-02-06 11:00:00'),
#  Timestamp('2024-02-06 12:00:00'),
#  Timestamp('2024-02-06 13:00:00'),
#  Timestamp('2024-07-01 00:00:00'),
#  Timestamp('2024-07-01 01:00:00'),
#  Timestamp('2024-07-01 02:00:00'),
#  Timestamp('2024-07-01 03:00:00'),
#  Timestamp('2024-07-01 04:00:00'),
#  Timestamp('2024-07-01 05:00:00'),
#  Timestamp('2024-07-01 06:00:00'),
#  Timestamp('2024-07-01 07:00:00'),
#  Timestamp('2024-07-01 08:00:00'),
#  Timestamp('2024-07-01 09:00:00'),
#  Timestamp('2024-07-01 10:00:00'),
#  Timestamp('2024-07-01 11:00:00'),
#  Timestamp('2024-07-01 12:00:00'),
#  Timestamp('2024-07-01 13:00:00'),
#  Timestamp('2024-07-01 14:00:00'),
#  Timestamp('2024-07-01 15:00:00'),
#  Timestamp('2024-07-01 16:00:00'),
#  Timestamp('2024-07-01 17:00:00'),
#  Timestamp('2024-07-01 18:00:00'),
# ...
